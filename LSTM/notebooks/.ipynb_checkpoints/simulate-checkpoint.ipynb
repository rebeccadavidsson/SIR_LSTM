# %%
import os
os.chdir("..")

# %%
from core.nn.LSTMmodel import LSTM
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import pickle
import datetime
import seaborn as sns
import covsirphy as cs
sns.set()
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
COUNTRY      = 'Japan'
DEVICE       = 'cpu'
TRAIN_UP_TO  = pd.to_datetime('2020-10-01')
ThreshConf   = 28
ThreshDead   = 20
target       = "New Confirmed"
FUTURE_DAYS  = 45

# %%
lstm = LSTM(COUNTRY, TRAIN_UP_TO, ThreshConf, ThreshDead, target)
# Out:
# Init LSTM model for Japan, trained up to 2020-10-01 00:00:00,                 with a Confirmed Cases threshold of 28                  and window size of 10

# %%
df = lstm.init_data()

# %%
lstm.simulate(ThreshConf=ThreshConf)
# Out:
# 100%|██████████| 10/10 [00:16<00:00,  1.70s/it, Loss =0.928, Lr=0.05]
# RMSLE : 0.55242  (not normalized)
# 0.5524227023124695

# %%
# lstm.optimizeTreshold()

# %%
from core.SIR import SIR

# %%
sir_sim = SIR(COUNTRY, TRAIN_UP_TO)

# %%
snl = sir_sim.init_data()

# %%
summary = snl.summary()
summary["Start_dt"] = pd.to_datetime(summary["Start"], format="%d%b%Y")
summary["End_dt"] = pd.to_datetime(summary["End"], format="%d%b%Y")
query = summary[summary["End_dt"] > TRAIN_UP_TO]
all_phases = query.index.tolist()

snl.combine(phases=all_phases)
target_date = datetime.datetime.strftime(TRAIN_UP_TO - datetime.timedelta(days=1), format="%d%b%Y")
snl.separate(target_date)

# %%
summary = snl.summary()

# %%
summary = snl.summary()
all_phases = summary.index.tolist()
snl.disable(phases=all_phases[:-1])
snl.enable(phases=all_phases[-1:])
snl.summary()
# Out:
#      Type      Start        End  Population
# 6th  Past  30Sep2020  24Jan2021   126529100

# %%
snl.estimate(model=cs.SIRF)
# Out:
# <SIR-F model: parameter estimation>
# Running optimization with 4 CPUs...
# 	 6th phase (30Sep2020 - 24Jan2021): finished 1428 trials in 3 min 50 sec
# Completed optimization. Total: 3 min 50 sec

# %%
df = snl.simulate();
df["New Confirmed"] = df["Confirmed"].diff()
# df.plot(x="Date", y="New Confirmed")

# %%
lstm.plot(SIRdata=df)

# %%
accuracy, dfOverTime = lstm.accuracy(SIRdata=df)
cm = sns.color_palette("coolwarm", as_cmap=True)
accuracy.style.background_gradient(cmap = cm, vmin=np.min(accuracy.values), vmax=np.max(accuracy.values))
# Out:
# <style  type="text/css" >
# #T_aa833_row0_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_aa833_row0_col1{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_aa833_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >lstm</th>        <th class="col_heading level0 col1" >SIRF</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aa833_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aa833_row0_col0" class="data row0 col0" >254.151466</td>
#                         <td id="T_aa833_row0_col1" class="data row0 col1" >311.154165</td>
#             </tr>
#     </tbody></table>

# %%
dfOverTime.plot()
