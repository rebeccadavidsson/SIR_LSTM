# %% [markdown]
# # Hybrid Model For Covid-19 Infection Predictions
# ## This model uses a SIR model variant to calculate model parameters associated with an intervention such as lockdown. Then, aspects of an LSTM model are combined with the benefits of a SIR model.
#
# Here, LSTM and SIR predictions are computed separately and combined using a rolling update mechanism. From the SIR model predictions, the parameters are calculated that are associated with a given type of NPI. The SIR predictions for a given NPI then serves as a biased input that is taken into account for new predictions with the LSTM model. Here, the rolling update mechanism ensures that the model is trained on data that includes SIR model bias.
#
# #### Rebecca Davidsson - 02/2021

# %%
import os
os.chdir("../LSTM")

# %%
from core.nn.LSTMmodel import LSTM

# %load_ext autoreload
# %autoreload 2

import pickle
import datetime
from numpy import array
import matplotlib.pylab as plt
import pandas as pd
import covsirphy as cs
import requests, io, json, urllib
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from itertools import cycle
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# ## Load timeseries data

# %%
# Download datasets
data_loader = cs.DataLoader("input")
jhu_data = data_loader.jhu()
population_data = data_loader.population()
oxcgrt_data = data_loader.oxcgrt()
# Out:
# Retrieving datasets from COVID-19 Data Hub: https://covid19datahub.io/
#
# Please set verbose=2 to see the detailed citation list.
#
#
# Retrieving COVID-19 dataset in Japan from https://github.com/lisphilar/covid19-sir/data/japan

# %%
COUNTRY = "Sweden"

# %% [markdown]
# ## Load governmental policy data (Non-pharmaceutical Interventions, or NPIs)

# %%
def get_periods(nums):
    nums = sorted(set(nums))
    gaps = [[s, e] for s, e in zip(nums, nums[1:]) if s+1 < e]
    edges = iter(nums[:1] + sum(gaps, []) + nums[-1:])
    return list(zip(edges, edges))
    
    
TARGET = "Stringency_index"
NPI_df = oxcgrt_data.cleaned()
NPI_df = NPI_df[NPI_df["Country"] == COUNTRY]

# Get lockdown dates
NPI_df = NPI_df.reset_index().drop('index', axis=1)
NPI_df = NPI_df.groupby("Date").mean().reset_index()
lockdown_indexes = NPI_df[NPI_df[TARGET] >= 75].index
lockdown_dates = NPI_df[NPI_df[TARGET] >= 75]["Date"]
periods = get_periods(lockdown_indexes)

if periods == []:
    lockdown_indexes = NPI_df[NPI_df[TARGET] >= 65].index
    lockdown_dates = NPI_df[NPI_df[TARGET] >= 65]["Date"]
    periods = get_periods(lockdown_indexes)
print(periods)
    
fig = px.line(NPI_df, x="Date", y=TARGET, title='Lockdown periods in ' + COUNTRY)
for dates in periods:
    fig.add_vrect(x0=NPI_df.iloc[dates[0]]["Date"], x1=NPI_df.iloc[dates[1]]["Date"], line_width=0, fillcolor="red", opacity=0.2)
fig.show()
# Out:
# [(341, 419)]
# <div>                            <div id="61d51814-a677-4849-af42-a815e6ce5a9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61d51814-a677-4849-af42-a815e6ce5a9f")) {                    Plotly.newPlot(                        "61d51814-a677-4849-af42-a815e6ce5a9f",                        [{"hovertemplate": "Date=%{x}<br>Stringency_index=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2020-01-01T00:00:00", "2020-01-02T00:00:00", "2020-01-03T00:00:00", "2020-01-04T00:00:00", "2020-01-05T00:00:00", "2020-01-06T00:00:00", "2020-01-07T00:00:00", "2020-01-08T00:00:00", "2020-01-09T00:00:00", "2020-01-10T00:00:00", "2020-01-11T00:00:00", "2020-01-12T00:00:00", "2020-01-13T00:00:00", "2020-01-14T00:00:00", "2020-01-15T00:00:00", "2020-01-16T00:00:00", "2020-01-17T00:00:00", "2020-01-18T00:00:00", "2020-01-19T00:00:00", "2020-01-20T00:00:00", "2020-01-21T00:00:00", "2020-01-22T00:00:00", "2020-01-23T00:00:00", "2020-01-24T00:00:00", "2020-01-25T00:00:00", "2020-01-26T00:00:00", "2020-01-27T00:00:00", "2020-01-28T00:00:00", "2020-01-29T00:00:00", "2020-01-30T00:00:00", "2020-01-31T00:00:00", "2020-02-01T00:00:00", "2020-02-02T00:00:00", "2020-02-03T00:00:00", "2020-02-04T00:00:00", "2020-02-05T00:00:00", "2020-02-06T00:00:00", "2020-02-07T00:00:00", "2020-02-08T00:00:00", "2020-02-09T00:00:00", "2020-02-10T00:00:00", "2020-02-11T00:00:00", "2020-02-12T00:00:00", "2020-02-13T00:00:00", "2020-02-14T00:00:00", "2020-02-15T00:00:00", "2020-02-16T00:00:00", "2020-02-17T00:00:00", "2020-02-18T00:00:00", "2020-02-19T00:00:00", "2020-02-20T00:00:00", "2020-02-21T00:00:00", "2020-02-22T00:00:00", "2020-02-23T00:00:00", "2020-02-24T00:00:00", "2020-02-25T00:00:00", "2020-02-26T00:00:00", "2020-02-27T00:00:00", "2020-02-28T00:00:00", "2020-02-29T00:00:00", "2020-03-01T00:00:00", "2020-03-02T00:00:00", "2020-03-03T00:00:00", "2020-03-04T00:00:00", "2020-03-05T00:00:00", "2020-03-06T00:00:00", "2020-03-07T00:00:00", "2020-03-08T00:00:00", "2020-03-09T00:00:00", "2020-03-10T00:00:00", "2020-03-11T00:00:00", "2020-03-12T00:00:00", "2020-03-13T00:00:00", "2020-03-14T00:00:00", "2020-03-15T00:00:00", "2020-03-16T00:00:00", "2020-03-17T00:00:00", "2020-03-18T00:00:00", "2020-03-19T00:00:00", "2020-03-20T00:00:00", "2020-03-21T00:00:00", "2020-03-22T00:00:00", "2020-03-23T00:00:00", "2020-03-24T00:00:00", "2020-03-25T00:00:00", "2020-03-26T00:00:00", "2020-03-27T00:00:00", "2020-03-28T00:00:00", "2020-03-29T00:00:00", "2020-03-30T00:00:00", "2020-03-31T00:00:00", "2020-04-01T00:00:00", "2020-04-02T00:00:00", "2020-04-03T00:00:00", "2020-04-04T00:00:00", "2020-04-05T00:00:00", "2020-04-06T00:00:00", "2020-04-07T00:00:00", "2020-04-08T00:00:00", "2020-04-09T00:00:00", "2020-04-10T00:00:00", "2020-04-11T00:00:00", "2020-04-12T00:00:00", "2020-04-13T00:00:00", "2020-04-14T00:00:00", "2020-04-15T00:00:00", "2020-04-16T00:00:00", "2020-04-17T00:00:00", "2020-04-18T00:00:00", "2020-04-19T00:00:00", "2020-04-20T00:00:00", "2020-04-21T00:00:00", "2020-04-22T00:00:00", "2020-04-23T00:00:00", "2020-04-24T00:00:00", "2020-04-25T00:00:00", "2020-04-26T00:00:00", "2020-04-27T00:00:00", "2020-04-28T00:00:00", "2020-04-29T00:00:00", "2020-04-30T00:00:00", "2020-05-01T00:00:00", "2020-05-02T00:00:00", "2020-05-03T00:00:00", "2020-05-04T00:00:00", "2020-05-05T00:00:00", "2020-05-06T00:00:00", "2020-05-07T00:00:00", "2020-05-08T00:00:00", "2020-05-09T00:00:00", "2020-05-10T00:00:00", "2020-05-11T00:00:00", "2020-05-12T00:00:00", "2020-05-13T00:00:00", "2020-05-14T00:00:00", "2020-05-15T00:00:00", "2020-05-16T00:00:00", "2020-05-17T00:00:00", "2020-05-18T00:00:00", "2020-05-19T00:00:00", "2020-05-20T00:00 ...

# %% [markdown]
# ## Calculate delay days for this country

# %%
s = cs.Scenario(jhu_data, population_data, country=COUNTRY)
days_delay, df_periods = s.estimate_delay(oxcgrt_data)
print(f'Delay days: {days_delay}')
days_delay = 26
# Out:
# Delay days: 12

# %% [markdown]
# ## Adjust data for delay days

# %%
lockdown_dates_adjusted = []
for date in lockdown_dates:
    new_date = date + datetime.timedelta(days = days_delay)
    lockdown_dates_adjusted.append(new_date)
lockdown_dates_adjusted = pd.Series(lockdown_dates_adjusted) 

# Save variable DELAY_START, which is equal to the start of a lockdown period
# in this case, we will hardcode the script to the second lockdown date
if len(periods) > 1:
    DELAY_START = NPI_df.iloc[periods[1][0]].Date
else:
    DELAY_START = NPI_df.iloc[periods[0][0]].Date

# %%
df = jhu_data.cleaned()
df = df[(df["Country"] == COUNTRY) & (df["Province"] == "-")]
df["New Confirmed"] = df["Confirmed"].diff()
df.plot(x="Date", y="New Confirmed");
for dates in periods:
    plt.axvline(x=NPI_df.iloc[dates[0]]["Date"], color="black", linestyle=":");
    plt.axvline(x=NPI_df.iloc[dates[1]]["Date"], color="black", linestyle=":");
plt.show()

# %% [markdown]
# ## Load model parameters over time

# %% [markdown]
# These model parameters were calculated with a phase dependent SIR model for multiple countries, using the covsirphy package.

# %%
df_params = pd.read_pickle("../figures/pickles/df_14_countries.p")
df_params["Country"].unique()
# Out:
# array(['Switzerland', 'Finland', 'Austria', 'Malaysia', 'Norway',
#        'Slovakia', 'Italy', 'Czech Republic', 'Portugal', 'Sweden',
#        'Germany', 'United Kingdom', 'Netherlands', 'Canada'], dtype=object)

# %%
df_params = df_params[df_params["Country"] == COUNTRY]

def plot_param(df, periods, TARGET):
    fig = px.line(df, x="Date", y=TARGET, title='Lockdown periods in the Netherlands')
    for dates in periods:
        fig.add_vrect(x0=NPI_df.iloc[dates[0]]["Date"], x1=NPI_df.iloc[dates[1]]["Date"], line_width=0, fillcolor="red", opacity=0.2)
    fig.show()
    
plot_param(df_params, periods, TARGET="Rt")
# Out:
# <div>                            <div id="4546506b-8b25-4424-9a67-1fd3ebc4ba5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4546506b-8b25-4424-9a67-1fd3ebc4ba5f")) {                    Plotly.newPlot(                        "4546506b-8b25-4424-9a67-1fd3ebc4ba5f",                        [{"hovertemplate": "Date=%{x}<br>Rt=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-21T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-22T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-23T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-24T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-25T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-26T00:00:00", "2020-02-27T00:00:00", "2020-02-27T00:00:00", "2020-02-27T00:00:00", "2020-02-27T00:00:00", "2020-02-27T00:00:00", "2020-02-27T00:00:00", "2020-02-27T00:00:00", "2020-02-27T00:00:00", "2020-02-27T00:00:00", "2020-02-27T00:00:00", "20 ...

# %% [markdown]
# ## Calculate model parameters for given intervention
#
# #### In this case, we will calculate the parameters associated with the lockdown
# #### NOTE: The DELAY is also included in the calculations by using the variable `lockdown_dates_adjusted`!

# %%
def calc_param(df, lockdown_dates):
    total_params = ["theta", "kappa", "rho", "sigma"]
    calc_params_df = {}
    for param in total_params:
        values = []
        for date in df["Date"].values:
            if date in lockdown_dates.values:
                values.append(np.mean(df[df['Date'] == date][param]))
        calc_params_df[param] = np.mean(values)
    return calc_params_df

params = calc_param(df_params, lockdown_dates_adjusted)
params
# Out:
# {'theta': 0.0006957838566708646,
#  'kappa': 9.641215709869649e-05,
#  'rho': 0.01026809435407464,
#  'sigma': 0.017601569322542147}

# %% [markdown]
# ### These calculated parameters are associated with a lockdown and can be used to predict future scenarios for the same type of intervention. Here we simulate this scenario using the SIR model. This can take up to 5 minutes.

# %%
TRAIN_UP_TO  = DELAY_START 

country_df = jhu_data.cleaned()
country_df = country_df[(country_df["Country"] == COUNTRY) & (country_df["Province"] == "-") ]
selection = country_df[country_df["Date"] == DELAY_START + datetime.timedelta(days_delay + 2)]

selection["Confirmed"] = abs(selection["Confirmed"].values[0] - selection["Confirmed"].values[0])
population_df = population_data.cleaned()
N = population_df[population_df["Country"] == COUNTRY]["Population"].values[0]
selection.head()
# Out:
#             Date Country Province  Confirmed  Infected  Fatal  Recovered
# 70929 2021-01-04  Sweden        -          0    459480  10172          0

# %%
from SIR_ODE import SIR
# Adjust for data inconsistency with some countries
target_column = "Confirmed"
if selection["Confirmed"].values[0] == 0:
    target_column = "Infected"
sir = SIR(N=N, I0=selection[target_column].values[0], R0=selection["Recovered"].values[0], 
          beta=params["rho"], gamma=params["theta"],
         days=85)

# %%
sns.set_style(style='dark')
SIR_results = sir.simulate(target="Infected")
# Out:
# 10175214 459480 0 9715734 0.01026809435407464 0.0006957838566708646

# %% [markdown]
# ## Run LSTM model

# %%
DEVICE       = 'cpu'
ThreshConf   = 70
ThreshDead   = 20
TARGET       = "New Confirmed"
TYPE         = "LSTMCell"

# %% [markdown]
# ## Add SIR-predictions as bias to LSTM model

# %%
def add_bias(results, BIAS):
    data = results.copy()
    preds = []
    SIR_data = []
    dates = []
    BIAS_START = DELAY_START + datetime.timedelta(days_delay)
    for date, pred, index in zip(data["valData"]["Date"], data["pred"], range(0, len(data["valData"]))):
        if date >= BIAS_START:
            preds.append(pred)
            dates.append(date)
            SIR_data.append(SIR_results["I"][index])
    plt.plot(dates, preds)
    plt.plot(data["valData"]["Date"], data["valData"]["ConfirmedCases"])
    plt.axvline(BIAS_START, color="black")

        
    # Add bias to prediction
    # Calculate trend in SIR-predictions
    x = np.arange(0,len(SIR_data))
    y = np.array(SIR_data)
    z = np.polyfit(x, y, 1)[0]

    new_preds, old_preds = [], []
    weight = 0.2
    for i in range(len(preds) - 1):
        diff = preds[i + 1] - preds[i]
        percent = (i+1) / len(preds)
        if i >= days_delay / 2:
            weight -= 0.005
        new_trend = (percent * z * i**(index/(min(preds)) + weight) + diff)
        new_trend = new_trend + diff
        new_preds.append(preds[i] + new_trend)
        old_preds.append(preds[i])
    plt.plot(dates[1:], new_preds)
    plt.show()
               
    # Add data to results
    data["total_old_pred"] = data["pred"]
    data["pred"] = new_preds
    data["oldpred"] = old_preds
    return data

# %% [markdown]
# ### Run LSTM model for n runs to compute average over n runs

# %%
BIAS = SIR_results["I"]
FUTURE_DAYS  = 85
iterations = 3
n_runs = 10

runs_without_bias, runs_with_bias = [], []

for _ in range(n_runs):
    lstm = LSTM(COUNTRY, TRAIN_UP_TO, FUTURE_DAYS, ThreshDead, TARGET, TYPE, DELAY_START)
    for i in range(iterations):
        results1 = lstm.simulate()
    # Add bias to predictions
    bias_results = add_bias(results1, BIAS)
    runs_with_bias.append(bias_results)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:14<00:00,  2.36s/it, Loss =0.0143, Lr=0.01]
# RMSLE : 0.29559  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:11<00:00,  1.84s/it, Loss =0.0152, Lr=0.01]
# RMSLE : 0.30701  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#  33%|███▎      | 2/6 [00:03<00:06,  1.55s/it, Loss =0.877, Lr=0.01]
# tensor(3512.8259, grad_fn=<AddBackward0>)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#   0%|          | 0/6 [00:01<?, ?it/s, Loss =0.188, Lr=0.01]
#  17%|█▋        | 1/6 [00:01<00:08,  1.70s/it, Loss =0.188, Lr=0.01]
#  17%|█▋        | 1/6 [00:03<00:08,  1.70s/it, Loss =5.11, Lr=0.01]
#  33%|███▎      | 2/6 [00:03<00:06,  1.67s/it, Loss =5.11, Lr=0.01]
#  33%|███▎      | 2/6 [00:04<00:06,  1.67s/it, Loss =0.137, Lr=0.01]
#  50%|█████     | 3/6 [00:04<00:04,  1.66s/it, Loss =0.137, Lr=0.01]
#  50%|█████     | 3/6 [00:06<00:04,  1.66s/it, Loss =0.0411, Lr=0.01]
#  67%|██████▋   | 4/6 [00:06<00:03,  1.69s/it, Loss =0.0411, Lr=0.01]
#  67%|██████▋   | 4/6 [00:09<00:03,  1.69s/it, Loss =0.0234, Lr=0.01]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.93s/it, Loss =0.0234, Lr=0.01]
#  83%|████████▎ | 5/6 [00:10<00:01,  1.93s/it, Loss =0.0193, Lr=0.01]
# 100%|██████████| 6/6 [00:10<00:00,  1.83s/it, Loss =0.0193, Lr=0.01]
#  33%|███▎      | 2/6 [00:18<00:36,  9.07s/it, Loss =0.877, Lr=0.01]
# RMSLE : 0.28730  (not normalized)
# RMSLE : 0.28730  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#  17%|█▋        | 1/6 [00:00<00:04,  1.08it/s, Loss =0.974, Lr=0.01]
# tensor(68.2045, grad_fn=<AddBackward0>)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#   0%|          | 0/6 [00:02<?, ?it/s, Loss =0.356, Lr=0.01]
#  17%|█▋        | 1/6 [00:02<00:10,  2.07s/it, Loss =0.356, Lr=0.01]
#  17%|█▋        | 1/6 [00:03<00:10,  2.07s/it, Loss =0.0467, Lr=0.01]
#  33%|███▎      | 2/6 [00:03<00:07,  1.98s/it, Loss =0.0467, Lr=0.01]
# tensor(1402.3376, grad_fn=<AddBackward0>)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#   0%|          | 0/6 [00:01<?, ?it/s, Loss =0.198, Lr=0.01]
#
#  17%|█▋        | 1/6 [00:01<00:08,  1.69s/it, Loss =0.198, Lr=0.01]
#
#  17%|█▋        | 1/6 [00:03<00:08,  1.69s/it, Loss =0.0917, Lr=0.01]
#
#  33%|███▎      | 2/6 [00:03<00:07,  1.77s/it, Loss =0.0917, Lr=0.01]
#
#  33%|███▎      | 2/6 [00:05<00:07,  1.77s/it, Loss =0.0302, Lr=0.01]
#
#  50%|█████     | 3/6 [00:05<00:05,  1.76s/it, Loss =0.0302, Lr=0.01]
#
#  50%|█████     | 3/6 [00:07<00:05,  1.76s/it, Loss =0.018, Lr=0.01]
#
#  67%|██████▋   | 4/6 [00:07<00:03,  1.85s/it, Loss =0.018, Lr=0.01]
#
#  67%|██████▋   | 4/6 [00:09<00:03,  1.85s/it, Loss =0.015, Lr=0.01]
#
#  83%|████████▎ | 5/6 [00:09<00:01,  1.84s/it, Loss =0.015, Lr=0.01]
#
#  83%|████████▎ | 5/6 [00:11<00:01,  1.84s/it, Loss =0.0142, Lr=0.01]
#
# 100%|██████████| 6/6 [00:11<00:00,  1.86s/it, Loss =0.0142, Lr=0.01]
#  33%|███▎      | 2/6 [00:18<00:36,  9.08s/it, Loss =0.0467, Lr=0.01]
# RMSLE : 0.29271  (not normalized)
#  17%|█▋        | 1/6 [00:22<01:50, 22.17s/it, Loss =0.974, Lr=0.01]
# RMSLE : 0.29271  (not normalized)
# RMSLE : 0.29271  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:10<00:00,  1.77s/it, Loss =0.0146, Lr=0.01]
# RMSLE : 0.30416  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:11<00:00,  1.91s/it, Loss =0.0138, Lr=0.01]
# RMSLE : 0.27235  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/it, Loss =0.0159, Lr=0.01]
# RMSLE : 0.30422  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:10<00:00,  1.77s/it, Loss =0.0138, Lr=0.01]
# RMSLE : 0.29611  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:11<00:00,  1.89s/it, Loss =0.0182, Lr=0.01]
# RMSLE : 0.27020  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:11<00:00,  1.95s/it, Loss =0.0142, Lr=0.01]
# RMSLE : 0.30203  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#  33%|███▎      | 2/6 [00:03<00:06,  1.66s/it, Loss =0.636, Lr=0.01]
# tensor(228294.4062, grad_fn=<AddBackward0>)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#   0%|          | 0/6 [00:01<?, ?it/s, Loss =0.315, Lr=0.01]
#  17%|█▋        | 1/6 [00:01<00:09,  1.98s/it, Loss =0.315, Lr=0.01]
#  17%|█▋        | 1/6 [00:04<00:09,  1.98s/it, Loss =2.61, Lr=0.01]
#  33%|███▎      | 2/6 [00:04<00:08,  2.01s/it, Loss =2.61, Lr=0.01]
#  33%|███▎      | 2/6 [00:06<00:08,  2.01s/it, Loss =0.701, Lr=0.01]
#  50%|█████     | 3/6 [00:06<00:06,  2.04s/it, Loss =0.701, Lr=0.01]
#  50%|█████     | 3/6 [00:08<00:06,  2.04s/it, Loss =0.278, Lr=0.01]
#  67%|██████▋   | 4/6 [00:08<00:04,  2.13s/it, Loss =0.278, Lr=0.01]
#  67%|██████▋   | 4/6 [00:10<00:04,  2.13s/it, Loss =0.0435, Lr=0.01]
#  83%|████████▎ | 5/6 [00:10<00:02,  2.09s/it, Loss =0.0435, Lr=0.01]
#  83%|████████▎ | 5/6 [00:12<00:02,  2.09s/it, Loss =0.0298, Lr=0.01]
# 100%|██████████| 6/6 [00:12<00:00,  2.06s/it, Loss =0.0298, Lr=0.01]
#  33%|███▎      | 2/6 [00:21<00:42, 10.55s/it, Loss =0.636, Lr=0.01]
# RMSLE : 0.30823  (not normalized)
# RMSLE : 0.30823  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:11<00:00,  1.85s/it, Loss =0.0361, Lr=0.01]
# RMSLE : 0.31646  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:10<00:00,  1.69s/it, Loss =0.0255, Lr=0.01]
# RMSLE : 0.29816  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:10<00:00,  1.80s/it, Loss =0.0172, Lr=0.01]
# RMSLE : 0.28508  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:10<00:00,  1.68s/it, Loss =0.025, Lr=0.01]
# RMSLE : 0.29919  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#  33%|███▎      | 2/6 [00:03<00:07,  1.77s/it, Loss =0.202, Lr=0.01]
# tensor(11778.4111, grad_fn=<AddBackward0>)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#   0%|          | 0/6 [00:01<?, ?it/s, Loss =0.582, Lr=0.01]
#  17%|█▋        | 1/6 [00:01<00:09,  1.85s/it, Loss =0.582, Lr=0.01]
# tensor(48247.6289, grad_fn=<AddBackward0>)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#   0%|          | 0/6 [00:01<?, ?it/s, Loss =0.684, Lr=0.01]
#
#  17%|█▋        | 1/6 [00:01<00:09,  1.92s/it, Loss =0.684, Lr=0.01]
# tensor(376.6154, grad_fn=<AddBackward0>)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#   0%|          | 0/6 [00:01<?, ?it/s, Loss =0.78, Lr=0.01]
#
#
#  17%|█▋        | 1/6 [00:01<00:07,  1.56s/it, Loss =0.78, Lr=0.01]
# tensor(435.2810, grad_fn=<AddBackward0>)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#   0%|          | 0/6 [00:01<?, ?it/s, Loss =0.161, Lr=0.01]
#
#
#
#  17%|█▋        | 1/6 [00:01<00:08,  1.63s/it, Loss =0.161, Lr=0.01]
#
#
#
#  17%|█▋        | 1/6 [00:03<00:08,  1.63s/it, Loss =0.0251, Lr=0.01]
#
#
#
#  33%|███▎      | 2/6 [00:03<00:06,  1.66s/it, Loss =0.0251, Lr=0.01]
#
#
#
#  33%|███▎      | 2/6 [00:05<00:06,  1.66s/it, Loss =0.0182, Lr=0.01]
#
#
#
#  50%|█████     | 3/6 [00:05<00:05,  1.69s/it, Loss =0.0182, Lr=0.01]
#
#
#
#  50%|█████     | 3/6 [00:06<00:05,  1.69s/it, Loss =0.0164, Lr=0.01]
#
#
#
#  67%|██████▋   | 4/6 [00:06<00:03,  1.71s/it, Loss =0.0164, Lr=0.01]
#
#
#
#  67%|██████▋   | 4/6 [00:08<00:03,  1.71s/it, Loss =0.0152, Lr=0.01]
#
#
#
#  83%|████████▎ | 5/6 [00:08<00:01,  1.73s/it, Loss =0.0152, Lr=0.01]
#
#
#
#  83%|████████▎ | 5/6 [00:10<00:01,  1.73s/it, Loss =0.0145, Lr=0.01]
#
#
#
# 100%|██████████| 6/6 [00:10<00:00,  1.75s/it, Loss =0.0145, Lr=0.01]
#  17%|█▋        | 1/6 [00:16<01:23, 16.69s/it, Loss =0.78, Lr=0.01]
# RMSLE : 0.28879  (not normalized)
#  17%|█▋        | 1/6 [00:23<01:55, 23.11s/it, Loss =0.684, Lr=0.01]
# RMSLE : 0.28879  (not normalized)
#  17%|█▋        | 1/6 [00:29<02:26, 29.31s/it, Loss =0.582, Lr=0.01]
# RMSLE : 0.28879  (not normalized)
#  33%|███▎      | 2/6 [00:38<01:16, 19.05s/it, Loss =0.202, Lr=0.01]
# RMSLE : 0.28879  (not normalized)
# RMSLE : 0.28879  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:10<00:00,  1.77s/it, Loss =0.0157, Lr=0.01]
# RMSLE : 0.30031  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:09<00:00,  1.62s/it, Loss =0.0764, Lr=0.01]
# RMSLE : 0.32559  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:09<00:00,  1.66s/it, Loss =0.0306, Lr=0.01]
# RMSLE : 0.27478  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:10<00:00,  1.77s/it, Loss =0.0154, Lr=0.01]
# RMSLE : 0.28500  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#  17%|█▋        | 1/6 [00:01<00:08,  1.69s/it, Loss =0.526, Lr=0.01]
# tensor(53.5226, grad_fn=<AddBackward0>)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#   0%|          | 0/6 [00:02<?, ?it/s, Loss =0.297, Lr=0.01]
#  17%|█▋        | 1/6 [00:02<00:11,  2.39s/it, Loss =0.297, Lr=0.01]
#  17%|█▋        | 1/6 [00:04<00:11,  2.39s/it, Loss =0.125, Lr=0.01]
#  33%|███▎      | 2/6 [00:04<00:08,  2.20s/it, Loss =0.125, Lr=0.01]
#  33%|███▎      | 2/6 [00:06<00:08,  2.20s/it, Loss =0.0241, Lr=0.01]
#  50%|█████     | 3/6 [00:06<00:06,  2.29s/it, Loss =0.0241, Lr=0.01]
#  50%|█████     | 3/6 [00:08<00:06,  2.29s/it, Loss =0.0201, Lr=0.01]
#  67%|██████▋   | 4/6 [00:08<00:04,  2.27s/it, Loss =0.0201, Lr=0.01]
#  67%|██████▋   | 4/6 [00:10<00:04,  2.27s/it, Loss =0.0174, Lr=0.01]
#  83%|████████▎ | 5/6 [00:10<00:02,  2.17s/it, Loss =0.0174, Lr=0.01]
#  83%|████████▎ | 5/6 [00:12<00:02,  2.17s/it, Loss =0.0159, Lr=0.01]
# 100%|██████████| 6/6 [00:12<00:00,  2.15s/it, Loss =0.0159, Lr=0.01]
#  17%|█▋        | 1/6 [00:19<01:39, 19.93s/it, Loss =0.526, Lr=0.01]
# RMSLE : 0.28625  (not normalized)
# RMSLE : 0.28625  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:10<00:00,  1.67s/it, Loss =0.0148, Lr=0.01]
# RMSLE : 0.29610  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:07<00:00,  1.28s/it, Loss =1.35, Lr=0.01]
# RMSLE : 0.65405  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#  17%|█▋        | 1/6 [00:00<00:04,  1.22it/s, Loss =0.421, Lr=0.01]
# tensor(28.7138, grad_fn=<AddBackward0>)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
#   0%|          | 0/6 [00:01<?, ?it/s, Loss =0.31, Lr=0.01]
#  17%|█▋        | 1/6 [00:01<00:08,  1.65s/it, Loss =0.31, Lr=0.01]
#  17%|█▋        | 1/6 [00:03<00:08,  1.65s/it, Loss =0.0371, Lr=0.01]
#  33%|███▎      | 2/6 [00:03<00:06,  1.66s/it, Loss =0.0371, Lr=0.01]
#  33%|███▎      | 2/6 [00:05<00:06,  1.66s/it, Loss =0.0293, Lr=0.01]
#  50%|█████     | 3/6 [00:05<00:05,  1.67s/it, Loss =0.0293, Lr=0.01]
#  50%|█████     | 3/6 [00:06<00:05,  1.67s/it, Loss =0.0241, Lr=0.01]
#  67%|██████▋   | 4/6 [00:06<00:03,  1.70s/it, Loss =0.0241, Lr=0.01]
#  67%|██████▋   | 4/6 [00:09<00:03,  1.70s/it, Loss =0.0231, Lr=0.01]
#  83%|████████▎ | 5/6 [00:09<00:01,  1.92s/it, Loss =0.0231, Lr=0.01]
#  83%|████████▎ | 5/6 [00:11<00:01,  1.92s/it, Loss =0.0231, Lr=0.01]
# 100%|██████████| 6/6 [00:11<00:00,  1.88s/it, Loss =0.0231, Lr=0.01]
#  17%|█▋        | 1/6 [00:14<01:13, 14.67s/it, Loss =0.421, Lr=0.01]
# RMSLE : 0.34991  (not normalized)
# RMSLE : 0.34991  (not normalized)
#   0%|          | 0/6 [00:00<?, ?it/s]
# Init LSTM model for Sweden, trained up to 2020-12-07 00:00:00, with a Confirmed Cases threshold of 70  and window size of 7
# 100%|██████████| 6/6 [00:06<00:00,  1.06s/it, Loss =2.13, Lr=0.01]
# RMSLE : 100000000000.00000  (not normalized)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-79ff704d208d> in <module>
#       8     lstm = LSTM(COUNTRY, TRAIN_UP_TO, FUTURE_DAYS, ThreshDead, TARGET, TYPE, DELAY_START)
#       9     for i in range(iterations):
# ---> 10         results1 = lstm.simulate()
#      11     # Add bias to predictions
#      12     bias_results = add_bias(results1, BIAS)
#
# ~/Desktop/SIR_LSTM/LSTM/core/nn/LSTMmodel.py in simulate(self, input_data, second, ThreshConf, pred)
#     133                                         alignThreshConf=ThreshConf,
#     134                                         alignThreshDead=self.ThreshDead,
# --> 135                                         errorFunc      =rmsle_error
#     136                                         )
#     137
#
# ~/Desktop/SIR_LSTM/LSTM/core/data/compare_countries.py in get_nearest_sequence(df, state, alignThreshConf, alignThreshDead, errorFunc)
#      66
#      67         # get candidate country
# ---> 68         confNeighDf = confDf[confDf['Province_State'] == neighbour].sort_values(by='Date', ascending=True)
#      69         deadNeighDf = deadDf[deadDf['Province_State'] == neighbour].sort_values(by='Date', ascending=True)
#      70
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5450
#    5451             by = by[0]
# -> 5452             k = self._get_label_or_level_values(by, axis=axis)
#    5453
#    5454             # need to rewrap column in Series to apply key function
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1675         if self._is_label_reference(key, axis=axis):
#    1676             self._check_label_or_level_ambiguity(key, axis=axis)
# -> 1677             values = self.xs(key, axis=other_axes[0])._values
#    1678         elif self._is_level_reference(key, axis=axis):
#    1679             values = self.axes[axis].get_level_values(key)._values
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3719         if axis == 1:
#    3720             if drop_level:
# -> 3721                 return self[key]
#    3722             index = self.columns
#    3723         else:
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2994                 if isinstance(self.columns, MultiIndex):
#    2995                     return self._getitem_multilevel(key)
# -> 2996                 return self._get_item_cache(key)
#    2997
#    2998         # Do we have a slicer (on rows)?
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    3788
#    3789             loc = self.columns.get_loc(item)
# -> 3790             values = self._mgr.iget(loc)
#    3791             res = self._box_col_values(values, loc).__finalize__(self)
#    3792
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/internals/managers.py in iget(self, i)
#    1001         """
#    1002         block = self.blocks[self.blknos[i]]
# -> 1003         values = block.iget(self.blklocs[i])
#    1004
#    1005         # shortcut for select a single-dim from a 2-dim BM
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/internals/blocks.py in iget(self, key)
#    2170         # GH#31649 we need to wrap scalars in Timestamp/Timedelta
#    2171         # TODO(EA2D): this can be removed if we ever have 2D EA
# -> 2172         return self.array_values().reshape(self.shape)[key]
#    2173
#    2174     def diff(self, n: int, axis: int = 0) -> List["Block"]:
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/arrays/datetimelike.py in __getitem__(self, key)
#     283             return result
#     284
# --> 285         result._freq = self._get_getitem_freq(key)
#     286         return result
#     287
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/arrays/datetimelike.py in _get_getitem_freq(self, key)
#     290         Find the `freq` attribute to assign to the result of a __getitem__ lookup.
#     291         """
# --> 292         is_period = is_period_dtype(self.dtype)
#     293         if is_period:
#     294             freq = self.freq
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_period_dtype(arr_or_dtype)
#     494     if arr_or_dtype is None:
#     495         return False
# --> 496     return PeriodDtype.is_dtype(arr_or_dtype)
#     497
#     498
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/dtypes/dtypes.py in is_dtype(cls, dtype)
#     940             else:
#     941                 return False
# --> 942         return super().is_dtype(dtype)
#     943
#     944     @classmethod
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#     252         return cls()
#     253
# --> 254     @classmethod
#     255     def is_dtype(cls, dtype: object) -> bool:
#     256         """
#
# KeyboardInterrupt:

# %%
predictions_with_bias, predictions_without_bias, total_old = [], [], []
for i in range(len(runs_with_bias)):
    predictions_with_bias.append(runs_with_bias[i]["pred"])
    predictions_without_bias.append(runs_with_bias[i]["oldpred"])
    total_old.append(runs_with_bias[i]["total_old_pred"])

# Compute average over multiple lists
average_bias = np.average(predictions_with_bias, axis=0)
average = np.average(predictions_without_bias, axis=0)
average_total = np.average(total_old, axis=0)
x_axis  = [TRAIN_UP_TO + datetime.timedelta(days=x) for x in range(len(average))]

columns=["Date", "avg", "avg_bias", "avg_old"]
df_average = pd.DataFrame(columns=columns)
df_average["avg"] = average
df_average["avg_bias"] = average_bias
df_average["Date"] = x_axis


x_axis2 = [TRAIN_UP_TO - datetime.timedelta(days=x) - datetime.timedelta(days=1) for x in range(len(average_total) - len(average))]
df_temp = pd.DataFrame(columns=columns)
df_temp["Date"] = np.sort(x_axis2)

# %%
FACTOR = 0
# Create dataframe to plot
results_df = pd.DataFrame(columns=["Date", "Train", "Validation", "LSTM", "Hybrid", "Pred"])
results_df["Date"] = pd.concat([runs_with_bias[0]["trainData"]["Date"], runs_with_bias[0]["valData"]["Date"]])

results_df["Validation"] = runs_with_bias[0]["valData"]["ConfirmedCases"]
results_df["Train"] = runs_with_bias[0]["trainData"]["ConfirmedCases"]

# Set correct dates
results_df = results_df.reset_index()
results_df = results_df[results_df["Date"] <= df_average["Date"].values[-1]]

results_df["LSTM"].iloc[-len(df_average["avg"]):] = df_average["avg"]
results_df["Hybrid"].iloc[-len(df_average["avg_bias"]):] = df_average["avg_bias"]
results_df["Pred"].iloc[-len(df_average["avg_old"]):] = df_average["avg_old"]

# HARDCODED: query to get more details in plot
results_df_section = results_df.query("Date>='2020-10-01'")
results_df_section.plot(x="Date", y=["Train", "Validation", 'LSTM', 'Hybrid', 'Pred'])
results_df.to_pickle("hybrid_23-02" + COUNTRY + '.p')

# %% [markdown]
# ## Calculate
